# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-3.12.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (506 kB)
#      |████████████████████████████████| 506 kB 25.1 MB/s eta 0:00:01
# Installing collected packages: pymongo
# Successfully installed pymongo-3.12.1
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.12.1)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.1.0-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 23.5 MB/s eta 0:00:01
# Installing collected packages: dnspython
# Successfully installed dnspython-2.1.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.1.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.2.0-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.6 MB/s  eta 0:00:01
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.11.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tweepy) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (1.26.7)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 56.9 MB/s eta 0:00:01
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.1 requests-oauthlib-1.3.0 tweepy-4.2.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.5 MB/s  eta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-9353a18873cb> in <module>
#       2 config.read('config.ini')
#       3
# ----> 4 CONSUMER_KEY      = config['mytwitter']['api_key']
#       5 CONSUMER_SECRET   = config['mytwitter']['api_secrete']
#       6 OAUTH_TOKEN       = config['mytwitter']['access_token']
#
# ~/anaconda3/envs/python3/lib/python3.6/configparser.py in __getitem__(self, key)
#     957     def __getitem__(self, key):
#     958         if key != self.default_section and not self.has_section(key):
# --> 959             raise KeyError(key)
#     960         return self._proxies[key]
#     961
#
# KeyError: 'mytwitter'

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9353a18873cb> in <module>
#       2 config.read('config.ini')
#       3
# ----> 4 CONSUMER_KEY      = config['mytwitter']['api_key']
#       5 CONSUMER_SECRET   = config['mytwitter']['api_secrete']
#       6 OAUTH_TOKEN       = config['mytwitter']['access_token']
#
# ~/anaconda3/envs/python3/lib/python3.6/configparser.py in __getitem__(self, key)
#     957     def __getitem__(self, key):
#     958         if key != self.default_section and not self.has_section(key):
# --> 959             raise KeyError(key)
#     960         return self._proxies[key]
#     961
#
# KeyError: 'mytwitter'

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9353a18873cb> in <module>
# ----> 1 config = configparser.ConfigParser()
#       2 config.read('config.ini')
#       3
#       4 CONSUMER_KEY      = config['mytwitter']['api_key']
#       5 CONSUMER_SECRET   = config['mytwitter']['api_secrete']
#
# NameError: name 'configparser' is not defined

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']

# %%
client = MongoClient(mongod_connect)
db = client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'id_1'

# %%
rest_auth = twitter.oauth.OAuth(OAUTH_TOKEN,OATH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
rest_api = twitter.Twitter(auth=rest_auth)

# %%
count = 100 #number of returned tweets, default and max is 100
geocode = "38.4392897,-78.9412224,50mi"  # defin the location, in Harrisonburg, VA
q = "election"                               #define the keywords, tweets contain election

# %%
search_results = rest_api.search.tweets( count=count,q=q, geocode=geocode) #you can use both q and geocode
statuses = search_results["statuses"]
since_id_new = statuses[-1]['id']
for statuse in statuses:
    try:
        tweet_collection.insert_one(statuse)
        pprint(statuse['created_at'])# print the date of the collected tweets
    except:
        pass
# Out:
# 'Tue Nov 02 19:42:13 +0000 2021'
# 'Tue Nov 02 19:37:15 +0000 2021'
# 'Tue Nov 02 19:35:47 +0000 2021'
# 'Tue Nov 02 19:32:12 +0000 2021'
# 'Tue Nov 02 19:32:10 +0000 2021'
# 'Tue Nov 02 19:30:32 +0000 2021'
# 'Tue Nov 02 19:30:00 +0000 2021'
# 'Tue Nov 02 19:27:38 +0000 2021'
# 'Tue Nov 02 19:17:19 +0000 2021'
# 'Tue Nov 02 19:12:16 +0000 2021'
# 'Tue Nov 02 19:03:15 +0000 2021'
# 'Tue Nov 02 18:49:27 +0000 2021'
# 'Tue Nov 02 18:49:27 +0000 2021'
# 'Tue Nov 02 18:44:51 +0000 2021'
# 'Tue Nov 02 18:42:59 +0000 2021'
# 'Tue Nov 02 18:38:57 +0000 2021'
# 'Tue Nov 02 18:38:01 +0000 2021'
# 'Tue Nov 02 18:35:28 +0000 2021'
# 'Tue Nov 02 18:33:48 +0000 2021'
# 'Tue Nov 02 18:31:06 +0000 2021'
# 'Tue Nov 02 18:30:28 +0000 2021'
# 'Tue Nov 02 18:26:18 +0000 2021'
# 'Tue Nov 02 18:24:35 +0000 2021'
# 'Tue Nov 02 18:12:19 +0000 2021'
# 'Tue Nov 02 18:07:27 +0000 2021'
# 'Tue Nov 02 18:05:11 +0000 2021'
# 'Tue Nov 02 18:02:30 +0000 2021'
# 'Tue Nov 02 18:00:54 +0000 2021'
# 'Tue Nov 02 17:53:10 +0000 2021'
# 'Tue Nov 02 17:50:08 +0000 2021'
# 'Tue Nov 02 17:47:18 +0000 2021'
# 'Tue Nov 02 14:44:29 +0000 2021'
# 'Tue Nov 02 14:44:25 +0000 2021'
# 'Tue Nov 02 14:43:03 +0000 2021'
# 'Tue Nov 02 14:41:22 +0000 2021'
# 'Tue Nov 02 14:41:18 +0000 2021'
# 'Tue Nov 02 14:28:51 +0000 2021'
# 'Tue Nov 02 14:26:02 +0000 2021'
# 'Tue Nov 02 14:24:42 +0000 2021'
# 'Tue Nov 02 14:23:49 +0000 2021'
# 'Tue Nov 02 14:20:57 +0000 2021'

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-3.12.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (506 kB)
#      |████████████████████████████████| 506 kB 21.9 MB/s eta 0:00:01
# Installing collected packages: pymongo
# Successfully installed pymongo-3.12.1
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.3.0-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.8 MB/s  eta 0:00:01
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.11.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tweepy) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.11.1->tweepy) (1.26.7)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 32.3 MB/s eta 0:00:01
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.1 requests-oauthlib-1.3.0 tweepy-4.3.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.8 MB/s  eta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']

# %%
client = MongoClient(mongod_connect)
db = client.lab9 # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'id_1'

# %%
stream_auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
stream_auth.set_access_token(OAUTH_TOKEN, OATH_TOKEN_SECRET)

strem_api = tweepy.API(stream_auth)

# %%
track = ['election'] # define the keywords, tweets contain election

locations = [-78.9326449,38.4150904,-78.8816972,38.4450731] #defin the location, in Harrisonburg, VA

# %%
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        print (status.id_str)
        try:
            tweet_collection.insert_one(status._json)
        except:
            pass
  
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = strem_api.auth, listener=myStreamListener)
myStream.filter(track=track)#  (locations = locations)   #Use either track or locations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-11bc45f21258> in <module>
# ----> 1 class MyStreamListener(tweepy.StreamListener):
#       2     def on_status(self, status):
#       3         print (status.id_str)
#       4         try:
#       5             tweet_collection.insert_one(status._json)
#
# AttributeError: module 'tweepy' has no attribute 'StreamListener'

# %%
rest_auth = twitter.oauth.OAuth(OAUTH_TOKEN,OATH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
rest_api = twitter.Twitter(auth=rest_auth)

# %%
count = 100 #number of returned tweets, default and max is 100
#geocode = "38.4392897,-78.9412224,50mi"  # defin the location, in Harrisonburg, VA
q = "covid19"                               #define the keywords, tweets contain election

# %%
search_results = rest_api.search.tweets( count=count,q=q) #you can use both q and geocode
statuses = search_results["statuses"]
since_id_new = statuses[-1]['id']
for statuse in statuses:
    try:
        tweet_collection.insert_one(statuse)
        pprint(statuse['created_at'])# print the date of the collected tweets
    except:
        pass
# Out:
# 'Thu Nov 04 19:04:45 +0000 2021'
# 'Thu Nov 04 19:04:45 +0000 2021'
# 'Thu Nov 04 19:04:44 +0000 2021'
# 'Thu Nov 04 19:04:44 +0000 2021'
# 'Thu Nov 04 19:04:44 +0000 2021'
# 'Thu Nov 04 19:04:44 +0000 2021'
# 'Thu Nov 04 19:04:44 +0000 2021'
# 'Thu Nov 04 19:04:42 +0000 2021'
# 'Thu Nov 04 19:04:41 +0000 2021'
# 'Thu Nov 04 19:04:40 +0000 2021'
# 'Thu Nov 04 19:04:40 +0000 2021'
# 'Thu Nov 04 19:04:40 +0000 2021'
# 'Thu Nov 04 19:04:40 +0000 2021'
# 'Thu Nov 04 19:04:39 +0000 2021'
# 'Thu Nov 04 19:04:39 +0000 2021'
# 'Thu Nov 04 19:04:38 +0000 2021'
# 'Thu Nov 04 19:04:37 +0000 2021'
# 'Thu Nov 04 19:04:37 +0000 2021'
# 'Thu Nov 04 19:04:37 +0000 2021'
# 'Thu Nov 04 19:04:36 +0000 2021'
# 'Thu Nov 04 19:04:35 +0000 2021'
# 'Thu Nov 04 19:04:35 +0000 2021'
# 'Thu Nov 04 19:04:35 +0000 2021'
# 'Thu Nov 04 19:04:34 +0000 2021'
# 'Thu Nov 04 19:04:34 +0000 2021'
# 'Thu Nov 04 19:04:34 +0000 2021'
# 'Thu Nov 04 19:04:33 +0000 2021'
# 'Thu Nov 04 19:04:33 +0000 2021'
# 'Thu Nov 04 19:04:33 +0000 2021'
# 'Thu Nov 04 19:04:32 +0000 2021'
# 'Thu Nov 04 19:04:32 +0000 2021'
# 'Thu Nov 04 19:04:32 +0000 2021'
# 'Thu Nov 04 19:04:32 +0000 2021'
# 'Thu Nov 04 19:04:31 +0000 2021'
# 'Thu Nov 04 19:04:30 +0000 2021'
# 'Thu Nov 04 19:04:30 +0000 2021'
# 'Thu Nov 04 19:04:30 +0000 2021'
# 'Thu Nov 04 19:04:29 +0000 2021'
# 'Thu Nov 04 19:04:29 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:28 +0000 2021'
# 'Thu Nov 04 19:04:27 +0000 2021'
# 'Thu Nov 04 19:04:27 +0000 2021'
# 'Thu Nov 04 19:04:26 +0000 2021'
# 'Thu Nov 04 19:04:25 +0000 2021'
# 'Thu Nov 04 19:04:24 +0000 2021'
# 'Thu Nov 04 19:04:24 +0000 2021'
# 'Thu Nov 04 19:04:24 +0000 2021'
# 'Thu Nov 04 19:04:24 +0000 2021'
# 'Thu Nov 04 19:04:24 +0000 2021'
# 'Thu Nov 04 19:04:23 +0000 2021'
# 'Thu Nov 04 19:04:23 +0000 2021'
# 'Thu Nov 04 19:04:23 +0000 2021'
# 'Thu Nov 04 19:04:22 +0000 2021'
# 'Thu Nov 04 19:04:21 +0000 2021'
# 'Thu Nov 04 19:04:20 +0000 2021'
# 'Thu Nov 04 19:04:20 +0000 2021'
# 'Thu Nov 04 19:04:20 +0000 2021'
# 'Thu Nov 04 19:04:20 +0000 2021'
# 'Thu Nov 04 19:04:19 +0000 2021'
# 'Thu Nov 04 19:04:19 +0000 2021'
# 'Thu Nov 04 19:04:19 +0000 2021'
# 'Thu Nov 04 19:04:19 +0000 2021'
# 'Thu Nov 04 19:04:18 +0000 2021'
# 'Thu Nov 04 19:04:18 +0000 2021'
# 'Thu Nov 04 19:04:18 +0000 2021'
# 'Thu Nov 04 19:04:17 +0000 2021'
# 'Thu Nov 04 19:04:16 +0000 2021'
# 'Thu Nov 04 19:04:16 +0000 2021'
# 'Thu Nov 04 19:04:16 +0000 2021'
# 'Thu Nov 04 19:04:15 +0000 2021'
# 'Thu Nov 04 19:04:15 +0000 2021'
# 'Thu Nov 04 19:04:14 +0000 2021'
# 'Thu Nov 04 19:04:12 +0000 2021'
# 'Thu Nov 04 19:04:11 +0000 2021'
# 'Thu Nov 04 19:04:11 +0000 2021'
# 'Thu Nov 04 19:04:10 +0000 2021'
# 'Thu Nov 04 19:04:09 +0000 2021'
# 'Thu Nov 04 19:04:09 +0000 2021'
# 'Thu Nov 04 19:04:09 +0000 2021'
# 'Thu Nov 04 19:04:07 +0000 2021'
# 'Thu Nov 04 19:04:07 +0000 2021'
# 'Thu Nov 04 19:04:06 +0000 2021'
# 'Thu Nov 04 19:04:06 +0000 2021'
# 'Thu Nov 04 19:04:06 +0000 2021'
# 'Thu Nov 04 19:04:05 +0000 2021'
# 'Thu Nov 04 19:04:05 +0000 2021'
# 'Thu Nov 04 19:04:05 +0000 2021'
# 'Thu Nov 04 19:04:04 +0000 2021'
# 'Thu Nov 04 19:04:04 +0000 2021'
# 'Thu Nov 04 19:04:02 +0000 2021'
# 'Thu Nov 04 19:04:02 +0000 2021'
# 'Thu Nov 04 19:04:01 +0000 2021'
# 'Thu Nov 04 19:04:01 +0000 2021'
# 'Thu Nov 04 19:04:00 +0000 2021'
# 'Thu Nov 04 19:04:00 +0000 2021'

# %%
since_id_old = 0
while(since_id_new != since_id_old):
    since_id_old = since_id_new
    search_results = rest_api.search.tweets( count=count,q=q,
                         max_id= since_id_new)
    statuses = search_results["statuses"]
    since_id_new = statuses[-1]['id']
    for statuse in statuses:
        try:
            tweet_collection.insert_one(statuse)
            pprint(statuse['created_at']) # print the date of the collected tweets
        except:
            pass
# Out:
# 'Thu Nov 04 19:04:00 +0000 2021'
# 'Thu Nov 04 19:04:00 +0000 2021'
# 'Thu Nov 04 19:04:00 +0000 2021'
# 'Thu Nov 04 19:04:00 +0000 2021'
# 'Thu Nov 04 19:03:58 +0000 2021'
# 'Thu Nov 04 19:03:58 +0000 2021'
# 'Thu Nov 04 19:03:58 +0000 2021'
# 'Thu Nov 04 19:02:17 +0000 2021'
# 'Thu Nov 04 19:02:15 +0000 2021'
# 'Thu Nov 04 19:02:15 +0000 2021'
# 'Thu Nov 04 19:02:15 +0000 2021'
# 'Thu Nov 04 19:02:14 +0000 2021'
# 'Thu Nov 04 19:02:14 +0000 2021'
# 'Thu Nov 04 19:02:14 +0000 2021'
# 'Thu Nov 04 19:02:12 +0000 2021'
# 'Thu Nov 04 19:02:12 +0000 2021'
# 'Thu Nov 04 19:02:12 +0000 2021'
# 'Thu Nov 04 19:02:11 +0000 2021'
# 'Thu Nov 04 19:02:11 +0000 2021'
# 'Thu Nov 04 19:02:11 +0000 2021'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-154b4940423a> in <module>
#       3     since_id_old = since_id_new
#       4     search_results = rest_api.search.tweets( count=count,q=q,
# ----> 5                          max_id= since_id_new)
#       6     statuses = search_results["statuses"]
#       7     since_id_new = statuses[-1]['id']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in __call__(self, **kwargs)
#     362             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     363         else:
# --> 364             return self._handle_response(req, uri, arg_data, _timeout)
#     365
#     366     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     373                 context = ssl._create_unverified_context()
#     374             kwargs['context'] = context
# --> 375             handle = urllib_request.urlopen(req, **kwargs)
#     376             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#     377                 return handle
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1390         def https_open(self, req):
#    1391             return self.do_open(http.client.HTTPSConnection, req,
# -> 1392                 context=self._context, check_hostname=self._check_hostname)
#    1393
#    1394         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
#    1351                 raise URLError(err)
# -> 1352             r = h.getresponse()
#    1353         except:
#    1354             h.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in getresponse(self)
#    1377         try:
#    1378             try:
# -> 1379                 response.begin()
#    1380             except ConnectionError:
#    1381                 self.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(tweet_collection.estimated_document_count())# number of tweets collected

user_cursor = tweet_collection.distinct("user.id")
print (len(user_cursor)) # number of unique Twitter users
# Out:
# 298
# 276

# %%
since_id_old = 0
while(since_id_new != since_id_old):
    since_id_old = since_id_new
    search_results = rest_api.search.tweets( count=count,q=q,
                         max_id= since_id_new)
    statuses = search_results["statuses"]
    since_id_new = statuses[-1]['id']
    for statuse in statuses:
        try:
            tweet_collection.insert_one(statuse)
            pprint(statuse['created_at']) # print the date of the collected tweets
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     374             kwargs['context'] = context
# --> 375             handle = urllib_request.urlopen(req, **kwargs)
#     376             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-15-154b4940423a> in <module>
#       3     since_id_old = since_id_new
#       4     search_results = rest_api.search.tweets( count=count,q=q,
# ----> 5                          max_id= since_id_new)
#       6     statuses = search_results["statuses"]
#       7     since_id_new = statuses[-1]['id']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in __call__(self, **kwargs)
#     362             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     363         else:
# --> 364             return self._handle_response(req, uri, arg_data, _timeout)
#     365
#     366     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     404                 return []
#     405             else:
# --> 406                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     407
#     408     def _handle_response_with_retry(self, req, uri, arg_data, _timeout=None):
#
# TwitterHTTPError: Twitter sent status 429 for URL: 1.1/search/tweets.json using parameters: (count=100&max_id=1456335986800005126&oauth_consumer_key=oern9t47fk6eAqylUEmg01AJF&oauth_nonce=9687380078624619799&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1636053878&oauth_token=60388598-lBtzHrw6MEFRo23JxlTGeJf80D9FYkonpBgA1wlm3&oauth_version=1.0&q=covid19&oauth_signature=xOlZ5j9r3bhpT0TpEqaCb0EgjI4%3D)
# details: {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}

# %%
since_id_old = 0
while(since_id_new != since_id_old):
    since_id_old = since_id_new
    search_results = rest_api.search.tweets( count=count,q=q,
                         max_id= since_id_new)
    statuses = search_results["statuses"]
    since_id_new = statuses[-1]['id']
    for statuse in statuses:
        try:
            tweet_collection.insert_one(statuse)
            pprint(statuse['created_at']) # print the date of the collected tweets
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     374             kwargs['context'] = context
# --> 375             handle = urllib_request.urlopen(req, **kwargs)
#     376             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/anaconda3/envs/python3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-16-154b4940423a> in <module>
#       3     since_id_old = since_id_new
#       4     search_results = rest_api.search.tweets( count=count,q=q,
# ----> 5                          max_id= since_id_new)
#       6     statuses = search_results["statuses"]
#       7     since_id_new = statuses[-1]['id']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in __call__(self, **kwargs)
#     362             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     363         else:
# --> 364             return self._handle_response(req, uri, arg_data, _timeout)
#     365
#     366     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     404                 return []
#     405             else:
# --> 406                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     407
#     408     def _handle_response_with_retry(self, req, uri, arg_data, _timeout=None):
#
# TwitterHTTPError: Twitter sent status 429 for URL: 1.1/search/tweets.json using parameters: (count=100&max_id=1456335986800005126&oauth_consumer_key=oern9t47fk6eAqylUEmg01AJF&oauth_nonce=7645633042103516486&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1636053925&oauth_token=60388598-lBtzHrw6MEFRo23JxlTGeJf80D9FYkonpBgA1wlm3&oauth_version=1.0&q=covid19&oauth_signature=DoDiaG1qAYGzkb8fWR5Zmj1tGpQ%3D)
# details: {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}

# %%
tweet_collection.create_index([("text", pymongo.TEXT)], name='text_index', default_language='english') # create a text index
# Out:
# 'text_index'

# %%
tweet_cursor = tweet_collection.find({"$text": {"$search": "covid"}}) # return tweets contain vote

# %%
for document in tweet_cursor[0:10]: # display the first 10 tweets from the query
    try:
        print ('----')
#         pprint (document) # use pprint to print the entire tweet document
   
        print ('name:', document["user"]["name"]) # user name
        print ('text:', document["text"])         # tweets
    except:
        print ("***error in encoding")
        pass
# Out:
# ----
# name: B S Bedi
# text: RT @yooelre: Merck's Covid pill approved by UK regulator, #COVID19
# An antiviral pill found to be effective at treating Covid-19 has been ap…
# ----
# name: Nathan Joyner
# text: Daily US Covid Deaths by County For MS   2021-11-02:  Updated Covid insights from our data scientists and USAFacts… https://t.co/HkxWaODzia
# ----
# name: La🌴rese Prince 🌷🍒
# text: RT @washingtonpost: British regulators approve pill for covid-19 treatment, the first authorization for the Merck drug molnupiravir in the…
# ----
# name: Ganvolo Fox @FE?
# text: RT @UHhospitals: Who is currently eligible for COVID-19 vaccine boosters? Use the below infographic as a guide and visit https://t.co/KZroE…
# ----
# name: あや
# text: RT @NewsDigestWeb: 【北海道で新たに4人感染確認 1人死亡】
#
# 北海道+4（合計60591人）
# ※札幌市3人、旭川市1人
# ※札幌市で70代男性が死亡
#
# 詳細は下記URLより：
# https://t.co/oEslL3ucOx
#
# #新型コロナウイルス #COVID…
# ----
# name: William Quincy Belle
# text: RT @wqbelle: The enemy is us.
#
# https://t.co/8sgqS2KF6h
#
# from 2019: Yes, we are our own worst enemy. There's nobody else to blame!
#
# #Covid #…
# ----
# name: #StayHome
# text: RT @wqbelle: The enemy is us.
#
# https://t.co/8sgqS2KF6h
#
# from 2019: Yes, we are our own worst enemy. There's nobody else to blame!
#
# #Covid #…
# ----
# name: #SaveSheikhJarra #SaveSilwan #BDS #Yemen #Kashmir
# text: RT @DrEricDing: The “kids rarely get sick from COVID” crowd need to sit down and stop endangering kids. It’s not just deaths (they happen!)…
# ----
# name: MSUN
# text: RT @DrEricDing: The “kids rarely get sick from COVID” crowd need to sit down and stop endangering kids. It’s not just deaths (they happen!)…
# ----
# name: Joseph Healy
# text: RT @DrEricDing: The “kids rarely get sick from COVID” crowd need to sit down and stop endangering kids. It’s not just deaths (they happen!)…

# %%
tweet_cursor = tweet_collection.find({"$text": {"$search": "vaccine"}}) # return tweets contain vote

# %%
for document in tweet_cursor[0:10]: # display the first 10 tweets from the query
    try:
        print ('----')
#         pprint (document) # use pprint to print the entire tweet document
   
        print ('name:', document["user"]["name"]) # user name
        print ('text:', document["text"])         # tweets
    except:
        print ("***error in encoding")
        pass
# Out:
# ----
# name: Paula Penfold
# text: RT @KlynchStuff: Raw vaccine data can be very (very) misleading. The fact that more vaccinated people die/are hospitalised in a highly vacc…
# ----
# name: Samcharms68
# text: RT @keithbaldrey: Ontario's flip flop on vaccine mandates for health care workers is 100% based on politics. BC's vaccine mandate for same…
# ----
# name: bev101
# text: RT @keithbaldrey: Ontario's flip flop on vaccine mandates for health care workers is 100% based on politics. BC's vaccine mandate for same…
# ----
# name: brokenrock
# text: RT @BogochIsaac: An important 3rd dose #COVID19 vaccine point in ON:
#
# &gt; 70: Can use Pfizer or Moderna vaccine, but if Moderna, use the "ful…
# ----
# name: Barry Cole 🌸
# text: RT @FreedomPodcast1: 82.1% of the latest #COVID19 deaths in England were #vaccinated
# 79.3% were FULLY vaccinated
#
# A total 3,085 COVID19 d…
# ----
# name: Freedom Podcast
# text: 82.1% of the latest #COVID19 deaths in England were #vaccinated
# 79.3% were FULLY vaccinated
#
# A total 3,085 COVID1… https://t.co/VBTi6TeI3Q
# ----
# name: Richard ❌ Hahn
# text: When 99% are force vaccinated and #COVID19 still rages, whose fault will it be?
# ----
# name: Newy
# text: RT @EduEngineer: This thread is a list of nations that have vaccinated at least 70% of their populations, and how they're doing on a cases/…
# ----
# name: Belfast Learning City
# text: RT @dcsdcouncil: With advice and information on #COVID19 vaccines being regularly updated, the Department of Health have shared the latest…
# ----
# name: lesley oneill
# text: RT @Casey0k: Almost at 3000 vaccinations! Thanks to all the @GMMH_NHS staff, boosting their immunity! #BoostYourImmunity #COVIDvaccine #Flu…

# %%
tweet_df = pd.DataFrame(list(tweet_cursor ))
tweet_df[:10] #display the first 10 tweets
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
tweet_cursor = tweet_collection.find({"$text": {"$search": "vaccine"}}) # return tweets contain vote

# %%
tweet_df = pd.DataFrame(list(tweet_cursor ))
tweet_df[:10] #display the first 10 tweets
# Out:
#                         _id                      created_at  \
# 0  618431056e17659abc8c4806  Thu Nov 04 19:02:20 +0000 2021
# 1  618431036e17659abc8c479e  Thu Nov 04 19:03:12 +0000 2021
# 2  61842ece6e17659abc8c46fd  Thu Nov 04 19:04:38 +0000 2021
# 3  61842ecf6e17659abc8c471c  Thu Nov 04 19:04:27 +0000 2021
# 4  61842ecf6e17659abc8c4718  Thu Nov 04 19:04:28 +0000 2021
# 5  618431056e17659abc8c480d  Thu Nov 04 19:02:17 +0000 2021
# 6  618431046e17659abc8c47be  Thu Nov 04 19:02:55 +0000 2021
# 7  618431056e17659abc8c4805  Thu Nov 04 19:02:20 +0000 2021
# 8  61842ecf6e17659abc8c4737  Thu Nov 04 19:04:16 +0000 2021
# 9  618431046e17659abc8c47b7  Thu Nov 04 19:03:01 +0000 2021
#
#                     id               id_str  \
# 0  1456336023760224256  1456336023760224256
# 1  1456336243294277652  1456336243294277652
# 2  1456336602066653204  1456336602066653204
# 3  1456336556093054982  1456336556093054982
# 4  1456336561944006657  1456336561944006657
# 5  1456336014289539081  1456336014289539081
# 6  1456336170795864064  1456336170795864064
# 7  1456336024527941640  1456336024527941640
# 8  1456336510278586378  1456336510278586378
# 9  1456336198465728516  1456336198465728516
#
#                                                 text  truncated  \
# 0  RT @KlynchStuff: Raw vaccine data can be very ...      False
# 1  RT @keithbaldrey: Ontario's flip flop on vacci...      False
# 2  RT @keithbaldrey: Ontario's flip flop on vacci...      False
# 3  RT @BogochIsaac: An important 3rd dose #COVID1...      False
# 4  RT @FreedomPodcast1: 82.1% of the latest #COVI...      False
# 5  82.1% of the latest #COVID19 deaths in England...       True
# 6  When 99% are force vaccinated and #COVID19 sti...      False
# 7  RT @EduEngineer: This thread is a list of nati...      False
# 8  RT @dcsdcouncil: With advice and information o...      False
# 9  RT @Casey0k: Almost at 3000 vaccinations! Than...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 4  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 5  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 6  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 9  {'hashtags': [{'text': 'BoostYourImmunity', 'i...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
# 5  {'iso_language_code': 'en', 'result_type': 're...
# 6  {'iso_language_code': 'en', 'result_type': 're...
# 7  {'iso_language_code': 'en', 'result_type': 're...
# 8  {'iso_language_code': 'en', 'result_type': 're...
# 9  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 3  <a href="http://twitter.com/#!/download/ipad" ...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
# 5  <a href="http://twitter.com/#!/download/ipad" ...                    NaN
# 6  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 7  <a href="http://twitter.com/download/iphone" r...                    NaN
# 8  <a href="http://twitter.com/download/iphone" r...                    NaN
# 9  <a href="http://twitter.com/download/android" ...                    NaN
#
#    ...                                   retweeted_status  is_quote_status  \
# 0  ...  {'created_at': 'Thu Nov 04 18:43:57 +0000 2021...            False
# 1  ...  {'created_at': 'Thu Nov 04 04:30:15 +0000 2021...            False
# 2  ...  {'created_at': 'Thu Nov 04 04:30:15 +0000 2021...            False
# 3  ...  {'created_at': 'Wed Nov 03 21:16:38 +0000 2021...            False
# 4  ...  {'created_at': 'Thu Nov 04 19:02:17 +0000 2021...            False
# 5  ...                                                NaN            False
# 6  ...                                                NaN            False
# 7  ...  {'created_at': 'Thu Nov 04 10:01:41 +0000 2021...            False
# 8  ...  {'created_at': 'Thu Nov 04 19:00:01 +0000 2021...            False
# 9  ...  {'created_at': 'Tue Nov 02 20:58:33 +0000 2021...            False
#
#   retweet_count favorite_count favorited retweeted lang possibly_sensitive  \
# 0             4              0     False     False   en                NaN
# 1           113              0     False     False   en                NaN
# 2           113              0     False     False   en                NaN
# 3            20              0     False     False   en                NaN
# 4             1              0     False     False   en                NaN
# 5             4              3     False     False   en              False
# 6             0              0     False     False   en                NaN
# 7           210              0     False     False   en                NaN
# 8             1              0     False     False   en                NaN
# 9             2              0     False     False   en                NaN
#
#   quoted_status_id quoted_status_id_str
# 0              NaN                  NaN
# 1              NaN                  NaN
# 2              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
# 5              NaN                  NaN
# 6              NaN                  NaN
# 7              NaN                  NaN
# 8              NaN                  NaN
# 9              NaN                  NaN
#
# [10 rows x 29 columns]

# %%
tweet_df["favorite_count"].hist() # create a histogram show the favorite count
# Out:
# <AxesSubplot:>
